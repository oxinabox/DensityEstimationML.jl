# %%
using DensityEstimationML

# %%
using Plots

# %%
histogram(rand(GenerateDatasets.magdon_ismail_and_atiya), nbins=25)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 28.9273,375.813 580.315,375.813 580.315,11.811 28.9273,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="28" y="11" width="552" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   142.066,370.353 142.066,17.2711
#   "/>
# ...

# %% [markdown]
# Check against images in Likas 2001 https://pdfs.semanticscholar.org/0aea/e2b793cd05801c1b94052c76e07be48b3139.pdf

# %%
histogram(rand(GenerateDatasets.likas_1), nbins=100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.5169,375.813 580.315,375.813 580.315,11.811 35.5169,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="11" width="546" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   160.658,370.353 160.658,17.2711
#   "/>
# ...

# %%
histogram(rand(GenerateDatasets.likas_2); nbins=200, xlims=[1,2,3,2])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.5169,375.813 580.315,375.813 580.315,11.811 35.5169,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="11" width="546" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   54.7713,370.353 54.7713,17.2711
#   "/>
# ...

# %%
histogram(rand(GenerateDatasets.likas_2); nbins=200)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 35.5169,375.813 580.315,375.813 580.315,11.811 35.5169,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="35" y="11" width="546" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   50.9357,370.353 50.9357,17.2711
#   "/>
# ...

# %%
likas_3_samples = rand(GenerateDatasets.likas_3)
histogram2d(likas_3_samples[1,:], likas_3_samples[2,:], xlims=(-1,2), ylims=(-1,2))
# Out:
# WARNING: Keyword argument match_dimensions not supported with Plots.GRBackend().  Choose from: Set(Symbol[:yticks, :zguidefont, :top_margin, :lims, :group, :zgridstyle, :foreground_color_border, :inset_subplots, :background_color, :xscale, :marker_z, :yforeground_color_text, :markerstrokealpha, :left_margin, :markeralpha, :xguidefont, :annotations, :window_title, :seriesalpha, :foreground_color_axis, :zlink, :ygridlinewidth, :seriescolor, :smooth, :zscale, :xticks, :y, :tickfont, :xgrid, :margin, :ygridalpha, :bottom_margin, :zdiscrete_values, :yforeground_color_border, :zlims, :colorbar, :framestyle, :zflip, :ticks, :zgridalpha, :scale, :linealpha, :background_color_legend, :linecolor, :overwrite_figure, :arrow, :normalize, :linestyle, :html_output_format, :zforeground_color_border, :foreground_color_legend, :title, :subplot_index, :xflip, :ytickfont, :zgrid, :fillcolor, :flip, :ygrid, :bar_width, :background_color_inside, :z, :bins, :yforeground_color_axis, :foreground_color_grid, 
# ...
