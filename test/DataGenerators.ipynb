# %%
using DensityEstimationML

# %%
using Plots

# %%
histogram(GenerateDatasets.magdon_ismail_and_atiya())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   159.308,370.85 159.308,13.4016
#   "/>
# ...

# %%
histogram(GenerateDatasets.likas_1(), nbins=100)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   167.604,370.85 167.604,13.4016
#   "/>
# ...

# %%
function GenerateDatasets.likas_2(n=5000)
    function sample()
        v=rand()/3
        u=6.5523v
        if (3+sqrt(2))u < 3
            # In linear part
            #Apply inverse CDF
            
            return 2sqrt(4+u)-4
        else
            
            # in quadratic part
            (1+sqrt(2))rand()+2(sqrt(9u^2 - 84u + 164) - 3u + 14)^(1/3)/2^(1/3) + (2(2^(1/3)))/(sqrt(9u^2 - 84u + 164) - 3u + 14)^(1/3) + 3
        end
    end
    [sample() for _ in 1:n]
end
histogram(GenerateDatasets.likas_2(); nbins=300)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   55.0141,370.85 55.0141,13.4016
#   "/>
# ...

# %%
# Out:
# DomainError:
#
# Stacktrace:
#  [1] (::#sample#8)() at ./In[15]:8
#  [2] collect_to!(::Array{Float64,1}, ::Base.Generator{UnitRange{Int64},##7#9{#sample#8}}, ::Int64, ::Int64) at ./array.jl:474
#  [3] collect(::Base.Generator{UnitRange{Int64},##7#9{#sample#8}}) at ./array.jl:442
#  [4] likas_2() at ./In[15]:2
#  [5] include_string(::String, ::String) at ./loading.jl:515

# %%
likas_3_samples = GenerateDatasets.likas_3()
histogram2d(likas_3_samples[1,:], likas_3_samples[2,:], xlims=(-1,2), ylims=(-1,2))
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="494" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:1; stroke-opacity:0.5; fill:none" stroke-dasharray="1, 2" points="
#   39.3701,370.85 39.3701,13.4016
#   "/>
# ...

# %%
gr()
# Out:
# Plots.GRBackend()
